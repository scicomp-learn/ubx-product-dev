# %% [markdown]
# # POC Bukalapak Scraping

# %%
# import things
import os

os.chdir('/Users/syahrulhamdani/Documents/Projects/unbotxing/')
print(f"Working directory -> {os.getcwd()}")

import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

from boxing import get_html, bl_make_soup
# Out:
# Working directory -> /Users/syahrulhamdani/Documents/Projects/unbotxing

# %%
# define site properties
url = "https://www.bukalapak.com"
print('url:', url)
sub_categories ={
    'handphone': ['hp-smartphone', 'tablet', 'headset-earphone', 'power-bank', 'aksesori-handphone'],
    'kamera': ['kamera-digital', 'kamera-analog', 'tas-case', 'aksesoris-kamera'],
    'elektronik': ['headphone', 'televisi', 'speaker'],
    'komputer': ['desktop', 'laptop', 'monitor', 'aksesoris']
    
}
print('category-subcategory:', sub_categories)
# Out:
# url: https://www.bukalapak.com
# category-subcategory: {'handphone': ['hp-smartphone', 'tablet', 'headset-earphone', 'power-bank', 'aksesori-handphone'], 'kamera': ['kamera-digital', 'kamera-analog', 'tas-case', 'aksesoris-kamera'], 'elektronik': ['headphone', 'televisi', 'speaker'], 'komputer': ['desktop', 'laptop', 'monitor', 'aksesoris']}

# %% [markdown]
# For POC purpose, and my business, I will focus on scraping product with query *iphone x*, with category `handphone` and subcategory `hp-smartphone`.

# %%
# make the soup
scrape_url = '/'.join([url, 'c', list(sub_categories.keys())[0], sub_categories['handphone'][0]])
param = {'search[keywords]': 'iphone x'}
raw_html, site_url = get_html(scrape_url, param)
soup, soup_url = bl_make_soup(scrape_url, param)

# %%
soup_url
# Out:
# 'https://www.bukalapak.com/c/handphone/hp-smartphone?search%5Bkeywords%5D=iphone+x'

# %%
# scraping
basic_products = soup.find(name='div', class_='basic-products')

# scrape the product title in `basic_products` soup
product_title = pd.Series(
    [product_card.find('a', class_='product__name')['title']
        for product_card in basic_products.find_all(
            'article', class_='product-display'
        )],
    name='product_title'
)
# scrape proudct href in `basic_products` soup
product_href = pd.Series(
    [url + product_card.find('a', class_='product__name')['href']
        for product_card in basic_products.find_all(
            'article', class_='product-display'
    )],
    name='product_url'
)
# scrape product review url
product_review_url = []
for product_card in basic_products.find_all('article', class_='product-display'):
    review_url = product_card.find('a', class_='review__aggregate')
    if review_url:
        product_review_url.append(url + review_url['href'])
    else:
        product_review_url.append(None)
product_review_url = pd.Series(product_review_url, name='review_url')

# concatenate into whole scraped bukalapak data
bl_data_product = pd.concat([product_title, product_href, product_review_url], axis=1)

# %%
bl_data_product
# Out:
#                                         product_title  \
# 0                                   Xiaomi Mi A2 Lite
# 1                        Iphone X 256gb seken likenew
# 2                              Apple Iphone X 256GIGA
# 3                                     Iphone XS 256GB
# 4                                            Iphone X
# 5                        iphone X 256gb seken fullset
# 6                               iPhone X 256GB mulus
# 7                                     Iphone XS 64GB
# 8                                  Iphone XS MAX 64GB
# 9                                    IPHONE X 256GIGA
# 10                                Iphone XS MAX 256GB
# 11                                Iphone X 64gb bekas
# 12                                 iphone X 256GB new
# 13                       Apple iPhone X 64 GiGA Byte
# 14                                      IPHONE X 64GB
# 15                                     Iphone XS 64GB
# 16                                Iphone XS Max 512GB
# 17                        Iphone X 64gb Bekas Fullset
# 18  IPHONE X 256 gb Silver Bukan 64 Mulus Fullset ...
# 19                                APPle iPHoNe xs MAX
# 20                       Iphone X 256gb Bekas Fullset
# 21  IPHONE X 10 TEN 64Gb Silver & Grey NEW Segel D...
# 22                       AppLe iPhoNe X 256 Giga Bite
# 23                IPHONE X 64GB GARANSI APPLE 1 TAHUN
# 24                       Apple iPhone X 256 GiGA Byte
# 25                    Iphone X 256GB - Seken Original
# 26               APPLE IPHONE X 256GB inter non aktif
# 27                                 Iphone X 256 Black
# 28                      APPLE IPHONE X 64GB INTER NEW
# 29                              iphone x 256gb RESMI
#
#                                           product_url  \
# 0   https://www.bukalapak.com/p/handphone/hp-smart...
# 1   https://www.bukalapak.com/p/handphone/hp-smart...
# 2   https://www.bukalapak.com/p/handphone/hp-smart...
# 3   https://www.bukalapak.com/p/handphone/hp-smart...
# 4   https://www.bukalapak.com/p/handphone/hp-smart...
# 5   https://www.bukalapak.com/p/handphone/hp-smart...
# 6   https://www.bukalapak.com/p/handphone/hp-smart...
# 7   https://www.bukalapak.com/p/handphone/hp-smart...
# 8   https://www.bukalapak.com/p/handphone/hp-smart...
# 9   https://www.bukalapak.com/p/handphone/hp-smart...
# 10  https://www.bukalapak.com/p/handphone/hp-smart...
# 11  https://www.bukalapak.com/p/handphone/hp-smart...
# 12  https://www.bukalapak.com/p/handphone/hp-smart...
# 13  https://www.bukalapak.com/p/handphone/hp-smart...
# 14  https://www.bukalapak.com/p/handphone/hp-smart...
# 15  https://www.bukalapak.com/p/handphone/hp-smart...
# 16  https://www.bukalapak.com/p/handphone/hp-smart...
# 17  https://www.bukalapak.com/p/handphone/hp-smart...
# 18  https://www.bukalapak.com/p/handphone/hp-smart...
# 19  https://www.bukalapak.com/p/handphone/hp-smart...
# 20  https://www.bukalapak.com/p/handphone/hp-smart...
# 21  https://www.bukalapak.com/p/handphone/hp-smart...
# 22  https://www.bukalapak.com/p/handphone/hp-smart...
# 23  https://www.bukalapak.com/p/handphone/hp-smart...
# 24  https://www.bukalapak.com/p/handphone/hp-smart...
# 25  https://www.bukalapak.com/p/handphone/hp-smart...
# 26  https://www.bukalapak.com/p/handphone/hp-smart...
# 27  https://www.bukalapak.com/p/handphone/hp-smart...
# 28  https://www.bukalapak.com/p/handphone/hp-smart...
# 29  https://www.bukalapak.com/p/handphone/hp-smart...
#
#                                            review_url
# 0   https://www.bukalapak.com/reviews/handphone/hp...
# 1   https://www.bukalapak.com/reviews/handphone/hp...
# 2   https://www.bukalapak.com/reviews/handphone/hp...
# 3   https://www.bukalapak.com/reviews/handphone/hp...
# 4   https://www.bukalapak.com/reviews/handphone/hp...
# 5   https://www.bukalapak.com/reviews/handphone/hp...
# 6   https://www.bukalapak.com/reviews/handphone/hp...
# 7   https://www.bukalapak.com/reviews/handphone/hp...
# 8   https://www.bukalapak.com/reviews/handphone/hp...
# 9   https://www.bukalapak.com/reviews/handphone/hp...
# 10  https://www.bukalapak.com/reviews/handphone/hp...
# 11  https://www.bukalapak.com/reviews/handphone/hp...
# 12  https://www.bukalapak.com/reviews/handphone/hp...
# 13  https://www.bukalapak.com/reviews/handphone/hp...
# 14  https://www.bukalapak.com/reviews/handphone/hp...
# 15  https://www.bukalapak.com/reviews/handphone/hp...
# 16  https://www.bukalapak.com/reviews/handphone/hp...
# 17  https://www.bukalapak.com/reviews/handphone/hp...
# 18  https://www.bukalapak.com/reviews/handphone/hp...
# 19  https://www.bukalapak.com/reviews/handphone/hp...
# 20                                               None
# 21  https://www.bukalapak.com/reviews/handphone/hp...
# 22  https://www.bukalapak.com/reviews/handphone/hp...
# 23                                               None
# 24  https://www.bukalapak.com/reviews/handphone/hp...
# 25                                               None
# 26  https://www.bukalapak.com/reviews/handphone/hp...
# 27  https://www.bukalapak.com/reviews/handphone/hp...
# 28                                               None
# 29                                               None
